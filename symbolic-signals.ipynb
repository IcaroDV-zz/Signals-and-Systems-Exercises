# %%
def f(x):
    return 2*x**2 - x + 4
x = float(input("Digite o valor de x: "))

print(f(x)) #input = 0
# Out:
# 4.0

# %%
import sympy as sp

# %%
x = sp.Symbol('x')
y = 2*x**2 - x + 4
sp.plot(y)
